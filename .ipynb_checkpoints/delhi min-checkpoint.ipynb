# %%
from neuralprophet import NeuralProphet

# %%
import pandas as pd
from matplotlib import pyplot as plt
import pickle

# %%
df=pd.read_csv('Mumbai_1990_2022_Santacruz.csv')

# %%
df.head()
# Out:
#          time  tavg  tmin  tmax  prcp
# 0  01-01-1990  23.2  17.0   NaN   0.0
# 1  02-01-1990  22.2  16.5  29.9   0.0
# 2  03-01-1990  21.8  16.3  30.7   0.0
# 3  04-01-1990  25.4  17.9  31.8   0.0
# 4  05-01-1990  26.5  19.3  33.7   0.0

# %%
df.dtypes
# Out:
# time     object
# tavg    float64
# tmin    float64
# tmax    float64
# prcp    float64
# dtype: object

# %%
df['time'] = pd.to_datetime(df['time'], format='%d-%m-%Y')

# %%
df.dtypes
# Out:
# time    datetime64[ns]
# tavg           float64
# tmin           float64
# tmax           float64
# prcp           float64
# dtype: object

# %%
plt.plot(df['time'],df['tmin'])

# %%
data=df[['time','tmin']]
data.dropna(inplace=True)
data.columns=['ds','y']
data.head()
# Out:
# WARNING - (py.warnings._showwarnmsg) - C:\Users\Amey\AppData\Local\Temp\ipykernel_10060\1344980971.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
#           ds     y
# 0 1990-01-01  17.0
# 1 1990-01-02  16.5
# 2 1990-01-03  16.3
# 3 1990-01-04  17.9
# 4 1990-01-05  19.3

# %%
import torch


device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
model=NeuralProphet()  #untrained neuralprophet model
model.fit(data,freq='D',epochs=1000)
# Out:
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 86.409% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# Finding best initial lr:   0%|          | 0/249 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]
#            MAE       RMSE      Loss  RegLoss  epoch
# 0    15.455049  19.056372  0.307838      0.0      0
# 1    13.065966  16.183603  0.229250      0.0      1
# 2    11.002872  13.670689  0.166364      0.0      2
# 3     9.285768  11.515926  0.118970      0.0      3
# 4     7.895704   9.770623  0.085259      0.0      4
# ..         ...        ...       ...      ...    ...
# 995   1.346127   1.734947  0.003177      0.0    995
# 996   1.346113   1.731146  0.003177      0.0    996
# 997   1.346101   1.733469  0.003177      0.0    997
# 998   1.346091   1.734765  0.003177      0.0    998
# 999   1.346088   1.734318  0.003177      0.0    999
#
# [1000 rows x 5 columns]

# %%
future=model.make_future_dataframe(data,periods=900)
forecast=model.predict(future)
forecast.head()
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 86.409% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.889% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.889% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# Predicting: 295it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
#           ds     y      yhat1      trend  season_yearly  season_weekly
# 0 2022-07-26  None  26.821835  24.111610       2.696996       0.013229
# 1 2022-07-27  None  26.863102  24.112373       2.712047       0.038681
# 2 2022-07-28  None  26.833841  24.113138       2.724879      -0.004176
# 3 2022-07-29  None  26.814043  24.113901       2.735277      -0.035136
# 4 2022-07-30  None  26.858006  24.114666       2.743031       0.000309

# %%
plot1=model.plot(forecast)

# %%
plot1
# Out:
# FigureWidgetResampler({
#     'data': [{'fill': 'none',
#               'line': {'color': 'rgba(45, 146, 255, 1.0)', 'width': 2},
#               'mode': 'lines',
#               'name': 'yhat1',
#               'type': 'scatter',
#               'uid': 'fd221fdf-7b2a-48cb-8d23-3b6dd01c2ea9',
#               'x': array([datetime.datetime(2022, 7, 26, 0, 0),
#                           datetime.datetime(2022, 7, 27, 0, 0),
#                           datetime.datetime(2022, 7, 28, 0, 0), ...,
#                           datetime.datetime(2025, 1, 8, 0, 0),
#                           datetime.datetime(2025, 1, 9, 0, 0),
#                           datetime.datetime(2025, 1, 10, 0, 0)], dtype=object),
#               'y': array([26.821835, 26.863102, 26.833841, ..., 18.8041  , 18.741238, 18.695131],
#                          dtype=float32)},
#              {'marker': {'color': 'black', 'size': 4},
#               'mode': 'markers',
#               'name': 'Actual',
#               'type': 'scatter',
#               'uid': '447e5675-3528-42c6-87ad-18ddd2d93b6d',
#               'x': array([datetime.datetime(2022, 7, 26, 0, 0),
#                           datetime.datetime(2022, 7, 27, 0, 0),
#                           datetime.datetime(2022, 7, 28, 0, 0), ...,
#                           datetime.datetime(2025, 1, 8, 0, 0),
#                           datetime.datetime(2025, 1, 9, 0, 0),
#                           datetime.datetime(2025, 1, 10, 0, 0)], dtype=object),
#               'y': array([nan, nan, nan, ..., nan, nan, nan])}],
#     'layout': {'autosize': True,
#                'font': {'size': 10},
#                'height': 420,
#                'hovermode': 'x unified',
#                'margin': {'b': 0, 'l': 0, 'pad': 0, 'r': 10, 't': 10},
#                'showlegend': True,
#                'template': '...',
#                'title': {'font': {'size': 12}},
#                'width': 700,
#                'xaxis': {'linewidth': 1.5,
#                          'mirror': True,
#                          'rangeselector': {'buttons': [{'count': 7, 'label': '1w', 'step': 'day', 'stepmode': 'backward'},
#                                                        {'count': 1,
#                                                         'label': '1m',
#                                                         'step': 'month',
#                                                         'stepmode': 'backward'},
#                                                        {'count': 6,
#                                                         'label': '6m',
#                                                         'step': 'month',
#                                                         'stepmode': 'backward'},
#                                                        {'count': 1, 'label': '1y', 'step': 'year', 'stepmode': 'backward'},
#                                                        {'step': 'all'}]},
#                          'rangeslider': {'visible': True},
#                          'showline': True,
#                          'title': {'text': 'ds'},
#                          'type': 'date'},
#                'yaxis': {'linewidth': 1.5, 'mirror': True, 'showline': True, 'title': {'text': 'y'}}}
# })

# %%
with open('mumbai_min_model.pkl','wb') as f:
    pickle.dump(model,f)
