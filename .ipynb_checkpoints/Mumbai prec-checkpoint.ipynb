# %%
from neuralprophet import NeuralProphet

# %%
import pandas as pd
from matplotlib import pyplot as plt
import pickle

# %%
df=pd.read_csv('Mumbai_1990_2022_Santacruz.csv')

# %%
df.head()
# Out:
#          time  tavg  tmin  tmax  prcp
# 0  01-01-1990  23.2  17.0   NaN   0.0
# 1  02-01-1990  22.2  16.5  29.9   0.0
# 2  03-01-1990  21.8  16.3  30.7   0.0
# 3  04-01-1990  25.4  17.9  31.8   0.0
# 4  05-01-1990  26.5  19.3  33.7   0.0

# %%
df.dtypes
# Out:
# time     object
# tavg    float64
# tmin    float64
# tmax    float64
# prcp    float64
# dtype: object

# %%
df['time'] = pd.to_datetime(df['time'], format='%d-%m-%Y')

# %%
df.dtypes
# Out:
# time    datetime64[ns]
# tavg           float64
# tmin           float64
# tmax           float64
# prcp           float64
# dtype: object

# %%
plt.plot(df['time'],df['tmax'])

# %%
data=df[['time','tmax']]
data.dropna(inplace=True)
data.columns=['ds','y']
data.head()
# Out:
# WARNING - (py.warnings._showwarnmsg) - C:\Users\Amey\AppData\Local\Temp\ipykernel_12612\2974680685.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
#           ds     y
# 1 1990-01-02  29.9
# 2 1990-01-03  30.7
# 3 1990-01-04  31.8
# 4 1990-01-05  33.7
# 5 1990-01-06  33.5

# %%
import torch


device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
model=NeuralProphet()  #untrained neuralprophet model
model.fit(data,freq='D',epochs=1000)
# Out:
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 90.077% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# Finding best initial lr:   0%|          | 0/250 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]
#            MAE       RMSE      Loss  RegLoss  epoch
# 0    12.751030  15.474636  0.407315      0.0      0
# 1    10.524263  12.793912  0.298447      0.0      1
# 2     8.471584  10.332236  0.204617      0.0      2
# 3     6.671302   8.145655  0.130348      0.0      3
# 4     5.184548   6.373121  0.078952      0.0      4
# ..         ...        ...       ...      ...    ...
# 995   1.342151   1.763193  0.006780      0.0    995
# 996   1.336697   1.755423  0.006691      0.0    996
# 997   1.335207   1.755410  0.006683      0.0    997
# 998   1.340755   1.762129  0.006724      0.0    998
# 999   1.336355   1.757046  0.006686      0.0    999
#
# [1000 rows x 5 columns]

# %%
future=model.make_future_dataframe(data,periods=900)
forecast=model.predict(future)
forecast.head()
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 90.077% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.889% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.889% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# Predicting: 313it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
#           ds     y      yhat1      trend  season_yearly  season_weekly
# 0 2022-07-26  None  30.045940  32.107014      -2.044744      -0.016329
# 1 2022-07-27  None  30.037334  32.106903      -2.045180      -0.024388
# 2 2022-07-28  None  30.080923  32.106789      -2.044539       0.018672
# 3 2022-07-29  None  30.012287  32.106678      -2.043139      -0.051252
# 4 2022-07-30  None  30.068832  32.106567      -2.041113       0.003379

# %%
plot1=model.plot(forecast)

# %%
plot1
# Out:
# FigureWidgetResampler({
#     'data': [{'fill': 'none',
#               'line': {'color': 'rgba(45, 146, 255, 1.0)', 'width': 2},
#               'mode': 'lines',
#               'name': 'yhat1',
#               'type': 'scatter',
#               'uid': '3ac9b94c-d16d-44a2-8b37-fe694db1dfb6',
#               'x': array([datetime.datetime(2022, 7, 26, 0, 0),
#                           datetime.datetime(2022, 7, 27, 0, 0),
#                           datetime.datetime(2022, 7, 28, 0, 0), ...,
#                           datetime.datetime(2025, 1, 8, 0, 0),
#                           datetime.datetime(2025, 1, 9, 0, 0),
#                           datetime.datetime(2025, 1, 10, 0, 0)], dtype=object),
#               'y': array([30.04594 , 30.037334, 30.080923, ..., 30.86216 , 30.882042, 30.79123 ],
#                          dtype=float32)},
#              {'marker': {'color': 'black', 'size': 4},
#               'mode': 'markers',
#               'name': 'Actual',
#               'type': 'scatter',
#               'uid': 'bc81fd89-f347-430a-8c57-c3db201a5f35',
#               'x': array([datetime.datetime(2022, 7, 26, 0, 0),
#                           datetime.datetime(2022, 7, 27, 0, 0),
#                           datetime.datetime(2022, 7, 28, 0, 0), ...,
#                           datetime.datetime(2025, 1, 8, 0, 0),
#                           datetime.datetime(2025, 1, 9, 0, 0),
#                           datetime.datetime(2025, 1, 10, 0, 0)], dtype=object),
#               'y': array([nan, nan, nan, ..., nan, nan, nan])}],
#     'layout': {'autosize': True,
#                'font': {'size': 10},
#                'height': 420,
#                'hovermode': 'x unified',
#                'margin': {'b': 0, 'l': 0, 'pad': 0, 'r': 10, 't': 10},
#                'showlegend': True,
#                'template': '...',
#                'title': {'font': {'size': 12}},
#                'width': 700,
#                'xaxis': {'linewidth': 1.5,
#                          'mirror': True,
#                          'rangeselector': {'buttons': [{'count': 7, 'label': '1w', 'step': 'day', 'stepmode': 'backward'},
#                                                        {'count': 1,
#                                                         'label': '1m',
#                                                         'step': 'month',
#                                                         'stepmode': 'backward'},
#                                                        {'count': 6,
#                                                         'label': '6m',
#                                                         'step': 'month',
#                                                         'stepmode': 'backward'},
#                                                        {'count': 1, 'label': '1y', 'step': 'year', 'stepmode': 'backward'},
#                                                        {'step': 'all'}]},
#                          'rangeslider': {'visible': True},
#                          'showline': True,
#                          'title': {'text': 'ds'},
#                          'type': 'date'},
#                'yaxis': {'linewidth': 1.5, 'mirror': True, 'showline': True, 'title': {'text': 'y'}}}
# })

# %%
with open('mumbai_max_model.pkl','wb') as f:
    pickle.dump(model,f)
